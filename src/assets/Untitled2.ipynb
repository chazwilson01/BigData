# %%
import requests
import csv
import os
from bs4 import BeautifulSoup

# Base URL (IMDb paginated search results)
BASE_URL = "https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start="
HEADERS = {"User-Agent": "Mozilla/5.0"}

# Directory for saving HTML pages
HTML_DIR = "html_data"
os.makedirs(HTML_DIR, exist_ok=True)

movies = []
MAX_PAGES = 80  # Adjust this to scrape more pages (each page has ~50 movies)

for page in range(1, MAX_PAGES * 50, 50):  # Loop for multiple pages
    url = f"{BASE_URL}{page}"
    print(f"Scraping page: {url}")  # Debugging output
    
    response = requests.get(url, headers=HEADERS)
    html_content = response.text
    
    # Save HTML to file
    html_filename = os.path.join(HTML_DIR, f"imdb_page_{page}.html")
    with open(html_filename, "w", encoding="utf-8") as f:
        f.write(html_content)
    
    # Parse the HTML
    soup = BeautifulSoup(html_content, 'html.parser')
    movie_blocks = soup.find_all("div", class_="ipc-metadata-list-summary-item__c")

    for index, movie in enumerate(movie_blocks, start=len(movies) + 1):
        try:
            # Extract movie details
            title_tag = movie.find("h3", class_="ipc-title__text")
            title = title_tag.text.strip() if title_tag else "N/A"

            year_tag = movie.find("span", class_="sc-d5ea4b9d-7")
            year = year_tag.text.strip() if year_tag else "N/A"

            rating_tag = movie.find("span", class_="ipc-rating-star--rating")
            rating = rating_tag.text.strip() if rating_tag else "N/A"

            genre_tag = movie.find("span", class_="sc-d5ea4b9d-4")
            genre = genre_tag.text.strip() if genre_tag else "N/A"

            desc_tag = movie.find("div", class_="ipc-html-content-inner-div")
            description = desc_tag.text.strip() if desc_tag else "N/A"

            movie_url_tag = movie.find("a", class_="ipc-title-link-wrapper")
            imdb_url = "https://www.imdb.com" + movie_url_tag["href"] if movie_url_tag else "N/A"

            image_tag = movie.find("img", class_="ipc-image")
            image_url = image_tag["src"] if image_tag else "N/A"

            movie_id = f"b{index}"

            movies.append([movie_id, title, year, rating, genre, description, imdb_url, image_url])

        except Exception as e:
            print(f"Skipping a movie due to an error: {e}")

# Save Data to CSV
def save_to_csv(filename, data):
    with open(filename, "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["ID", "Title", "Year", "Rating", "Genre", "Description", "IMDb URL", "Image URL"])
        writer.writerows(data)

save_to_csv("tableB.csv", movies)
print(f"Scraped {len(movies)} movies and saved to tableB.csv")
print(f"HTML pages saved in '{HTML_DIR}' directory")
# Out:
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=51
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=101
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=151
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=201
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=251
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=301
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=351
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=401
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=451
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=501
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=551
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=601
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=651
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=701
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=751
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=801
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=851
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=901
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=951
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1001
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1051
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1101
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1151
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1201
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1251
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1301
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1351
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1401
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1451
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1501
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1551
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1601
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1651
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1701
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1751
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1801
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1851
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1901
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=1951
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2001
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2051
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2101
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2151
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2201
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2251
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2301
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2351
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2401
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2451
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2501
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2551
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2601
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2651
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2701
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2751
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2801
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2851
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2901
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=2951
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3001
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3051
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3101
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3151
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3201
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3251
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3301
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3351
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3401
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3451
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3501
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3551
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3601
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3651
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3701
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3751
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3801
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3851
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3901
# Scraping page: https://www.imdb.com/search/title/?title_type=feature,tv_movie,tv_special,video,tv_series,tv_miniseries&interests=in0000001&start=3951
# Scraped 2000 movies and saved to tableB.csv
# HTML pages saved in 'html_data' directory

# %%
import requests
import csv
import os
from bs4 import BeautifulSoup

# Base URL (TMDb paginated search results)
BASE_URL = "https://www.themoviedb.org/tv?page="
HEADERS = {"User-Agent": "Mozilla/5.0"}

# Directory for saving HTML pages
HTML_DIR = "tmdb_html_data"
os.makedirs(HTML_DIR, exist_ok=True)

movies = []
MAX_PAGES = 100  # Adjust this to scrape more pages

for page in range(1, MAX_PAGES + 1):  # Loop for multiple pages
    url = f"{BASE_URL}{page}"
    print(f"Scraping page: {url}")  # Debugging output
    
    response = requests.get(url, headers=HEADERS)
    html_content = response.text

    # Save HTML to file
    html_filename = os.path.join(HTML_DIR, f"tmdb_page_{page}.html")
    with open(html_filename, "w", encoding="utf-8") as f:
        f.write(html_content)

    # Parse the HTML
    soup = BeautifulSoup(html_content, 'html.parser')
    movie_blocks = soup.find_all("div", class_="card style_1")
    
    for index, movie in enumerate(movie_blocks, start=len(movies) + 1):
        try:
            # Extract movie details
            title_tag = movie.find("h2").find("a")
            title = title_tag.text.strip() if title_tag else "N/A"

            year_tag = movie.find("p")  # The date is inside a <p> tag
            year = year_tag.text.strip() if year_tag else "N/A"

            rating_tag = movie.find("div", class_="user_score_chart")
            rating = rating_tag["data-percent"] if rating_tag else "N/A"

            image_tag = movie.find("img", class_="poster")
            image_url = image_tag["src"] if image_tag else "N/A"

            movie_url_tag = movie.find("a")
            tmdb_url = "https://www.themoviedb.org" + movie_url_tag["href"] if movie_url_tag else "N/A"

            movie_id = f"a{index}"

            movies.append([movie_id, title, year, rating, tmdb_url, image_url])

        except Exception as e:
            print(f"Skipping a movie due to an error: {e}")

# Save Data to CSV
def save_to_csv(filename, data):
    with open(filename, "w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["ID", "Title", "Year", "Rating", "TMDb URL", "Image URL"])
        writer.writerows(data)

save_to_csv("tableA.csv", movies)
print(f"Scraped {len(movies)} movies and saved to tableA.csv")
print(f"HTML pages saved in '{HTML_DIR}' directory")
# Out:
# Scraping page: https://www.themoviedb.org/tv?page=1
# Scraping page: https://www.themoviedb.org/tv?page=2
# Scraping page: https://www.themoviedb.org/tv?page=3
# Scraping page: https://www.themoviedb.org/tv?page=4
# Scraping page: https://www.themoviedb.org/tv?page=5
# Scraping page: https://www.themoviedb.org/tv?page=6
# Scraping page: https://www.themoviedb.org/tv?page=7
# Scraping page: https://www.themoviedb.org/tv?page=8
# Scraping page: https://www.themoviedb.org/tv?page=9
# Scraping page: https://www.themoviedb.org/tv?page=10
# Scraping page: https://www.themoviedb.org/tv?page=11
# Scraping page: https://www.themoviedb.org/tv?page=12
# Scraping page: https://www.themoviedb.org/tv?page=13
# Scraping page: https://www.themoviedb.org/tv?page=14
# Scraping page: https://www.themoviedb.org/tv?page=15
# Scraping page: https://www.themoviedb.org/tv?page=16
# Scraping page: https://www.themoviedb.org/tv?page=17
# Scraping page: https://www.themoviedb.org/tv?page=18
# Scraping page: https://www.themoviedb.org/tv?page=19
# Scraping page: https://www.themoviedb.org/tv?page=20
# Scraping page: https://www.themoviedb.org/tv?page=21
# Scraping page: https://www.themoviedb.org/tv?page=22
# Scraping page: https://www.themoviedb.org/tv?page=23
# Scraping page: https://www.themoviedb.org/tv?page=24
# Scraping page: https://www.themoviedb.org/tv?page=25
# Scraping page: https://www.themoviedb.org/tv?page=26
# Scraping page: https://www.themoviedb.org/tv?page=27
# Scraping page: https://www.themoviedb.org/tv?page=28
# Scraping page: https://www.themoviedb.org/tv?page=29
# Scraping page: https://www.themoviedb.org/tv?page=30
# Scraping page: https://www.themoviedb.org/tv?page=31
# Scraping page: https://www.themoviedb.org/tv?page=32
# Scraping page: https://www.themoviedb.org/tv?page=33
# Scraping page: https://www.themoviedb.org/tv?page=34
# Scraping page: https://www.themoviedb.org/tv?page=35
# Scraping page: https://www.themoviedb.org/tv?page=36
# Scraping page: https://www.themoviedb.org/tv?page=37
